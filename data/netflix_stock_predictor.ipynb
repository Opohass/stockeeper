# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN, Input, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %% [markdown]
# Import Data

# %%
df = pd.read_csv('NFLX.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-10-23  194.169998  194.899994  191.029999  192.470001  192.470001
# 1  2017-10-24  192.750000  196.740005  191.399994  196.020004  196.020004
# 2  2017-10-25  195.380005  197.059998  193.009995  193.770004  193.770004
# 3  2017-10-26  194.660004  197.610001  194.080002  195.210007  195.210007
# 4  2017-10-27  197.199997  200.649994  196.220001  199.539993  199.539993
#
#     Volume
# 0  6980000
# 1  7069100
# 2  5315300
# 3  5185800
# 4  8128600

# %% [markdown]
# ``We Are Only Interested In Closing Prices And Dates, So Let's Fix That``

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (1259, 7)

# %% [markdown]
# Dropping Irrelevant Columns

# %%
df.drop(["Open","High","Low", "Adj Close", "Volume"], inplace=True, axis=1)
df
# Out:
#             Date       Close
# 0     2017-10-23  192.470001
# 1     2017-10-24  196.020004
# 2     2017-10-25  193.770004
# 3     2017-10-26  195.210007
# 4     2017-10-27  199.539993
# ...          ...         ...
# 1254  2022-10-17  245.100006
# 1255  2022-10-18  240.860001
# 1256  2022-10-19  272.380005
# 1257  2022-10-20  268.160004
# 1258  2022-10-21  289.570007
#
# [1259 rows x 2 columns]

# %% [markdown]
# Making The Date Column Our Index And Normalizing Values

# %%
dates = df["Date"]
# Converting Dates To Numbers
normalized_dates = []
for i in dates:
    normalized_dates.append(round(((pd.to_datetime(i).year-2017)+(pd.Period(i).dayofyear/365)),3))
df_norm = pd.DataFrame(data=df["Close"].values, index=normalized_dates, columns=["Close"])
df_norm
# Out:
#             Close
# 0.811  192.470001
# 0.814  196.020004
# 0.816  193.770004
# 0.819  195.210007
# 0.822  199.539993
# ...           ...
# 5.795  245.100006
# 5.797  240.860001
# 5.800  272.380005
# 5.803  268.160004
# 5.805  289.570007
#
# [1259 rows x 1 columns]

# %% [markdown]
# Plotting Data

# %%
plt.figure(figsize=(12,8))
plt.plot(df_norm)
plt.xlabel("Year (2017 - Today)")
plt.ylabel("Value In USD")
plt.title("Apple Stock Prices")
plt.show()

# %% [markdown]
# Scaling Our Data, Inserting Into

# %%
scaler = MinMaxScaler()
norm_close_val = scaler.fit_transform(df_norm)
norm_close_val
df_norm["Close"] = norm_close_val
num_df = np.array(norm_close_val)
df_norm
# Out:
#           Close
# 0.811  0.049684
# 0.814  0.056442
# 0.816  0.052159
# 0.819  0.054900
# 0.822  0.063142
# ...         ...
# 5.795  0.149871
# 5.797  0.141799
# 5.800  0.201801
# 5.803  0.193768
# 5.805  0.234524
#
# [1259 rows x 1 columns]

# %%
import pickle

def scaler_pickling(scaler, file_name):
    import pickle
    with open(file_name, "wb") as f:
        pickle.dump(scaler, f)

# %%
scaler_pickling(scaler, "flask_app/website/static/byte_models/netflix_scaler.pkl")

# %% [markdown]
# Splitting to training, testing and validation sets
# train set: 0.70
# test set: 0.20
# val set: 0.10

# %%
total_len = len(num_df)-365
train_test_val = np.around([total_len * 0.7, total_len * 0.1, total_len * 0.2], decimals=0)
train_test_val = [int(i) for i in train_test_val]
train_test_val
# Out:
# [626, 89, 179]

# %% [markdown]
# train set = 626
# val set = 89
# test set = 179

# %% [markdown]
# Our Time Step Will Be 365 Days

# %%
X_train = []
y_train = []
X_val = []
y_val = []
X_test = []
y_test = []
time_step = 365
for i in range(time_step, len(num_df)):
    # Train Set
    if i < time_step + train_test_val[0]:
        X_train.append(num_df[i-time_step:i,0])
        y_train.append(num_df[i,0])
    elif time_step + train_test_val[0] <= i < time_step + train_test_val[0] + train_test_val[1]:
        X_val.append(num_df[i-time_step:i,0])
        y_val.append(num_df[i,0])
    else:
        X_test.append(num_df[i-time_step:i,0])
        y_test.append(num_df[i,0])

X_train = np.array(X_train)
y_train = np.array(y_train)

X_val = np.array(X_val)
y_val = np.array(y_val)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
print(len(X_train))
print(len(X_val))
print(len(X_test))
# Out:
# 626
# 89
# 179

# %% [markdown]
# Checking Our Shapes

# %%
X_train.shape
# Out:
# (626, 365)

# %% [markdown]
# We Want Our Shape To Be (x,x,1) for X
# and (x,1) for y

# %%
# For Train Sets
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
y_train = y_train.reshape(y_train.shape[0], 1)
print("X Train Shape:",X_train.shape, "| y Train Shape:", y_train.shape)
# Out:
# X Train Shape: (626, 365, 1) | y Train Shape: (626, 1)

# %%
# For val Sets
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
y_val = y_val.reshape(y_val.shape[0], 1)
print("X val Shape:",X_val.shape, "| y val Shape:", y_val.shape)
# Out:
# X val Shape: (89, 365, 1) | y val Shape: (89, 1)

# %%
# For test Sets
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
y_test = y_test.reshape(y_test.shape[0], 1)
print("X test Shape:",X_test.shape, "| y test Shape:", y_test.shape)
# Out:
# X test Shape: (179, 365, 1) | y test Shape: (179, 1)

# %% [markdown]
# Our Sets Are Ready Time To Set Up Our Model

# %%
regressor = Sequential()

regressor.add(LSTM(units=180, return_sequences=True, input_shape=(X_train.shape[1],1)))
# regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=365, return_sequences=True))
# regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=180, return_sequences=True))
# regressor.add(Dropout(0.2))
regressor.add(LSTM(units=180, return_sequences=False))
regressor.add(Dense(25))
regressor.add(Dense(1))

# %% [markdown]
# Compiling Using Adam

# %%
regressor.compile(optimizer=Adam(learning_rate=0.0026), loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %% [markdown]
# #### Summary

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 180)          131040
#
#  lstm_1 (LSTM)               (None, 180)               259920
#
#  dense (Dense)               (None, 25)                4525
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 395,511
# Trainable params: 395,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Plotting Model Structure

# %%
tf.keras.utils.plot_model(regressor, show_shapes=True)

# %% [markdown]
# Training The Model

# %%
hist = regressor.fit(X_train,
                     y_train,
                     validation_data=(X_val, y_val),
                     epochs=10)
                     #callbacks=tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=0))
# Out:
# Epoch 1/10
# 2022-10-25 15:28:57.001997: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 20/20 [==============================] - 14s 609ms/step - loss: 0.0255 - root_mean_squared_error: 0.1598 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0903
# Epoch 2/10
# 20/20 [==============================] - 12s 591ms/step - loss: 0.0017 - root_mean_squared_error: 0.0411 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0725
# Epoch 3/10
# 20/20 [==============================] - 12s 594ms/step - loss: 0.0010 - root_mean_squared_error: 0.0324 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 4/10
# 20/20 [==============================] - 12s 595ms/step - loss: 9.5342e-04 - root_mean_squared_error: 0.0309 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0600
# Epoch 5/10
# 20/20 [==============================] - 12s 595ms/step - loss: 9.2120e-04 - root_mean_squared_error: 0.0304 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 6/10
# 20/20 [==============================] - 12s 592ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0605
# Epoch 7/10
# 20/20 [==============================] - 12s 599ms/step - loss: 7.9323e-04 - root_mean_squared_error: 0.0282 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0584
# Epoch 8/10
# 20/20 [==============================] - 12s 581ms/step - loss: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0781
# Epoch 9/10
# 20/20 [==============================] - 12s 588ms/step - loss: 0.0012 - root_mean_squared_error: 0.0353 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0590
# Epoch 10/10
# 20/20 [==============================] - 11s 569ms/step - loss: 7.6250e-04 - root_mean_squared_error: 0.0276 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565

# %% [markdown]
# Plotting Loss Over Time

# %%
pd.DataFrame(hist.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Predicting Baseline (train data)

# %%
y_train_pred = scaler.inverse_transform(regressor.predict(X_train))
y_train_true = scaler.inverse_transform(y_train)
plt.plot(y_train_pred, 'r')
plt.plot(y_train_true)
plt.legend(["Pred","Train"])
plt.show()
# Out:
# 20/20 [==============================] - 4s 165ms/step

# %% [markdown]
# Test Prediction

# %%
y_test_pred = scaler.inverse_transform(regressor.predict(X_test))
y_test_true = scaler.inverse_transform(y_test)
plt.plot(y_test_pred, 'r')
plt.plot(y_test_true)
plt.legend(["Pred","Train"])
plt.show()
# Out:
# 6/6 [==============================] - 1s 161ms/step

# %% [markdown]
# R2 Score For Model

# %%
np.round(r2_score(y_test_true, y_test_pred),decimals=2)
# Out:
# 0.93

# %% [markdown]
# 93% Accuracy For The Model IS An Amazing Result

# %% [markdown]
# Creating a pickled version

# %% [markdown]
# pickling function

# %%
import pickle

def file_pickling(model, file_name):
    import pickle
    with open(file_name, "wb") as f:
        pickle.dump(model, f)

# %%
file_pickling(regressor, "byte_models/netflix.pkl")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://7d01f316-511f-4cc3-830b-560261a0f43c/assets
# INFO:tensorflow:Assets written to: ram://7d01f316-511f-4cc3-830b-560261a0f43c/assets
