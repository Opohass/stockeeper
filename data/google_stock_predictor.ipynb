# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN, Input, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %% [markdown]
# Import Data

# %%
df = pd.read_csv('GOOGL.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-10-23  50.258999  50.289501  49.154999  49.277000  49.277000
# 1  2017-10-24  49.325001  49.463001  48.854000  49.424500  49.424500
# 2  2017-10-25  49.313499  49.721500  48.886002  49.573002  49.573002
# 3  2017-10-26  49.923500  50.325500  49.523499  49.570999  49.570999
# 4  2017-10-27  51.549500  53.181000  51.342499  51.683498  51.683498
#
#       Volume
# 0   32786000
# 1   28902000
# 2   30574000
# 3   47396000
# 4  103682000

# %% [markdown]
# ``We Are Only Interested In Closing Prices And Dates, So Let's Fix That``

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (1259, 7)

# %% [markdown]
# Dropping Irrelevant Columns

# %%
df.drop(["Open","High","Low", "Adj Close", "Volume"], inplace=True, axis=1)
df
# Out:
#             Date       Close
# 0     2017-10-23   49.277000
# 1     2017-10-24   49.424500
# 2     2017-10-25   49.573002
# 3     2017-10-26   49.570999
# 4     2017-10-27   51.683498
# ...          ...         ...
# 1254  2022-10-17   99.970001
# 1255  2022-10-18  100.769997
# 1256  2022-10-19   99.629997
# 1257  2022-10-20   99.970001
# 1258  2022-10-21  101.129997
#
# [1259 rows x 2 columns]

# %% [markdown]
# Making The Date Column Our Index And Normalizing Values

# %%
dates = df["Date"]
# Converting Dates To Numbers
normalized_dates = []
for i in dates:
    normalized_dates.append(round(((pd.to_datetime(i).year-2017)+(pd.Period(i).dayofyear/365)),3))
df_norm = pd.DataFrame(data=df["Close"].values, index=normalized_dates, columns=["Close"])
df_norm
# Out:
#             Close
# 0.811   49.277000
# 0.814   49.424500
# 0.816   49.573002
# 0.819   49.570999
# 0.822   51.683498
# ...           ...
# 5.795   99.970001
# 5.797  100.769997
# 5.800   99.629997
# 5.803   99.970001
# 5.805  101.129997
#
# [1259 rows x 1 columns]

# %% [markdown]
# Plotting Data

# %%
plt.figure(figsize=(12,8))
plt.plot(df_norm)
plt.xlabel("Year (2017 - Today)")
plt.ylabel("Value In USD")
plt.title("Apple Stock Prices")
plt.show()

# %% [markdown]
# Scaling Our Data, Inserting Into

# %%
scaler = MinMaxScaler()
norm_close_val = scaler.fit_transform(df_norm)
norm_close_val
df_norm["Close"] = norm_close_val
num_df = np.array(norm_close_val)
df_norm
# Out:
#           Close
# 0.811  0.000432
# 0.814  0.001899
# 0.816  0.003375
# 0.819  0.003355
# 0.822  0.024353
# ...         ...
# 5.795  0.504314
# 5.797  0.512266
# 5.800  0.500934
# 5.803  0.504314
# 5.805  0.515844
#
# [1259 rows x 1 columns]

# %%
import pickle

def scaler_pickling(scaler, file_name):
    import pickle
    with open(file_name, "wb") as f:
        pickle.dump(scaler, f)

# %%
scaler_pickling(scaler, "flask_app/website/static/byte_models/google_scaler.pkl")

# %% [markdown]
# Splitting to training, testing and validation sets
# train set: 0.70
# test set: 0.20
# val set: 0.10

# %%
total_len = len(num_df)-365
train_test_val = np.around([total_len * 0.7, total_len * 0.1, total_len * 0.2], decimals=0)
train_test_val = [int(i) for i in train_test_val]
train_test_val
# Out:
# [626, 89, 179]

# %% [markdown]
# train set = 626
# val set = 89
# test set = 179

# %% [markdown]
# Our Time Step Will Be 365 Days

# %%
X_train = []
y_train = []
X_val = []
y_val = []
X_test = []
y_test = []
time_step = 365
for i in range(time_step, len(num_df)):
    # Train Set
    if i < time_step + train_test_val[0]:
        X_train.append(num_df[i-time_step:i,0])
        y_train.append(num_df[i,0])
    elif time_step + train_test_val[0] <= i < time_step + train_test_val[0] + train_test_val[1]:
        X_val.append(num_df[i-time_step:i,0])
        y_val.append(num_df[i,0])
    else:
        X_test.append(num_df[i-time_step:i,0])
        y_test.append(num_df[i,0])

X_train = np.array(X_train)
y_train = np.array(y_train)

X_val = np.array(X_val)
y_val = np.array(y_val)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
print(len(X_train))
print(len(X_val))
print(len(X_test))
# Out:
# 626
# 89
# 179

# %% [markdown]
# Checking Our Shapes

# %%
X_train.shape
# Out:
# (626, 365)

# %% [markdown]
# We Want Our Shape To Be (x,x,1) for X
# and (x,1) for y

# %%
# For Train Sets
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
y_train = y_train.reshape(y_train.shape[0], 1)
print("X Train Shape:",X_train.shape, "| y Train Shape:", y_train.shape)
# Out:
# X Train Shape: (626, 365, 1) | y Train Shape: (626, 1)

# %%
# For val Sets
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
y_val = y_val.reshape(y_val.shape[0], 1)
print("X val Shape:",X_val.shape, "| y val Shape:", y_val.shape)
# Out:
# X val Shape: (89, 365, 1) | y val Shape: (89, 1)

# %%
# For test Sets
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
y_test = y_test.reshape(y_test.shape[0], 1)
print("X test Shape:",X_test.shape, "| y test Shape:", y_test.shape)
# Out:
# X test Shape: (179, 365, 1) | y test Shape: (179, 1)

# %% [markdown]
# Our Sets Are Ready Time To Set Up Our Model

# %%
regressor = Sequential()

regressor.add(LSTM(units=180, return_sequences=True, input_shape=(X_train.shape[1],1)))
# regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=365, return_sequences=True))
# regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=180, return_sequences=True))
# regressor.add(Dropout(0.2))
regressor.add(LSTM(units=180, return_sequences=False))
regressor.add(Dense(25))
regressor.add(Dense(1))

# %% [markdown]
# Compiling Using Adam

# %%
regressor.compile(optimizer=Adam(learning_rate=0.0026), loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %% [markdown]
# #### Summary

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 180)          131040
#
#  lstm_1 (LSTM)               (None, 180)               259920
#
#  dense (Dense)               (None, 25)                4525
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 395,511
# Trainable params: 395,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Plotting Model Structure

# %%
tf.keras.utils.plot_model(regressor, show_shapes=True)

# %% [markdown]
# Training The Model

# %%
hist = regressor.fit(X_train,
                     y_train,
                     validation_data=(X_val, y_val),
                     epochs=10)
                     #callbacks=tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=0))
# Out:
# Epoch 1/10
# 2022-10-25 15:23:48.895614: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 20/20 [==============================] - 14s 597ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 2/10
# 20/20 [==============================] - 12s 595ms/step - loss: 0.0012 - root_mean_squared_error: 0.0344 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0496
# Epoch 3/10
# 20/20 [==============================] - 12s 609ms/step - loss: 6.2930e-04 - root_mean_squared_error: 0.0251 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0632
# Epoch 4/10
# 20/20 [==============================] - 13s 627ms/step - loss: 7.4669e-04 - root_mean_squared_error: 0.0273 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0483
# Epoch 5/10
# 20/20 [==============================] - 13s 628ms/step - loss: 6.9820e-04 - root_mean_squared_error: 0.0264 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 6/10
# 20/20 [==============================] - 12s 616ms/step - loss: 5.1811e-04 - root_mean_squared_error: 0.0228 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0455
# Epoch 7/10
# 20/20 [==============================] - 12s 617ms/step - loss: 5.9108e-04 - root_mean_squared_error: 0.0243 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 8/10
# 20/20 [==============================] - 13s 630ms/step - loss: 7.4805e-04 - root_mean_squared_error: 0.0274 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 9/10
# 20/20 [==============================] - 13s 628ms/step - loss: 7.3228e-04 - root_mean_squared_error: 0.0271 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0379
# Epoch 10/10
# 20/20 [==============================] - 12s 624ms/step - loss: 4.5595e-04 - root_mean_squared_error: 0.0214 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439

# %% [markdown]
# Plotting Loss Over Time

# %%
pd.DataFrame(hist.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Predicting Baseline (train data)

# %%
y_train_pred = scaler.inverse_transform(regressor.predict(X_train))
y_train_true = scaler.inverse_transform(y_train)
plt.plot(y_train_pred, 'r')
plt.plot(y_train_true)
plt.legend(["Pred","Train"])
plt.show()
# Out:
# 20/20 [==============================] - 4s 185ms/step

# %% [markdown]
# Test Prediction

# %%
y_test_pred = scaler.inverse_transform(regressor.predict(X_test))
y_test_true = scaler.inverse_transform(y_test)
plt.plot(y_test_pred, 'r')
plt.plot(y_test_true)
plt.legend(["Pred","Train"])
plt.show()
# Out:
# 6/6 [==============================] - 1s 169ms/step

# %% [markdown]
# R2 Score For Model

# %%
np.round(r2_score(y_test_true, y_test_pred),decimals=2)
# Out:
# 0.86

# %% [markdown]
# 86% Accuracy For The Model IS A Good Starting Point

# %% [markdown]
# Creating a pickled version

# %% [markdown]
# pickling function

# %%
import pickle

def file_pickling(model, file_name):
    import pickle
    with open(file_name, "wb") as f:
        pickle.dump(model, f)

# %%
file_pickling(regressor, "byte_models/google.pkl")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://6dca676a-2825-4ef1-8d71-6bde1bd9bfca/assets
# INFO:tensorflow:Assets written to: ram://6dca676a-2825-4ef1-8d71-6bde1bd9bfca/assets
