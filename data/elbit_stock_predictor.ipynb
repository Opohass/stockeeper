# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN, Input, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %% [markdown]
# Import Data

# %%
df = pd.read_csv('ESLT.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-10-23  148.410004  149.570007  148.000000  149.300003  140.855103
# 1  2017-10-24  150.449997  151.460007  150.369995  151.220001  142.666519
# 2  2017-10-25  150.250000  150.639999  149.229996  150.600006  142.081573
# 3  2017-10-26  149.720001  150.990005  149.500000  149.759995  141.289108
# 4  2017-10-27  149.309998  151.029999  149.250000  150.839996  142.307983
#
#    Volume
# 0   40100
# 1   32500
# 2   15400
# 3   16800
# 4   13600

# %% [markdown]
# ``We Are Only Interested In Closing Prices And Dates, So Let's Fix That``

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (1259, 7)

# %% [markdown]
# Dropping Irrelevant Columns

# %%
df.drop(["Open","High","Low", "Adj Close", "Volume"], inplace=True, axis=1)
df
# Out:
#             Date       Close
# 0     2017-10-23  149.300003
# 1     2017-10-24  151.220001
# 2     2017-10-25  150.600006
# 3     2017-10-26  149.759995
# 4     2017-10-27  150.839996
# ...          ...         ...
# 1254  2022-10-17  207.240005
# 1255  2022-10-18  208.770004
# 1256  2022-10-19  207.539993
# 1257  2022-10-20  202.759995
# 1258  2022-10-21  204.750000
#
# [1259 rows x 2 columns]

# %% [markdown]
# Making The Date Column Our Index And Normalizing Values

# %%
dates = df["Date"]
# Converting Dates To Numbers
normalized_dates = []
for i in dates:
    normalized_dates.append(round(((pd.to_datetime(i).year-2017)+(pd.Period(i).dayofyear/365)),3))
df_norm = pd.DataFrame(data=df["Close"].values, index=normalized_dates, columns=["Close"])
df_norm
# Out:
#             Close
# 0.811  149.300003
# 0.814  151.220001
# 0.816  150.600006
# 0.819  149.759995
# 0.822  150.839996
# ...           ...
# 5.795  207.240005
# 5.797  208.770004
# 5.800  207.539993
# 5.803  202.759995
# 5.805  204.750000
#
# [1259 rows x 1 columns]

# %% [markdown]
# Plotting Data

# %%
plt.figure(figsize=(12,8))
plt.plot(df_norm)
plt.xlabel("Year (2017 - Today)")
plt.ylabel("Value In USD")
plt.title("Apple Stock Prices")
plt.show()

# %% [markdown]
# Scaling Our Data, Inserting Into

# %%
scaler = MinMaxScaler()
norm_close_val = scaler.fit_transform(df_norm)
norm_close_val
df_norm["Close"] = norm_close_val
num_df = np.array(norm_close_val)
df_norm
# Out:
#           Close
# 0.811  0.293693
# 0.814  0.307973
# 0.816  0.303362
# 0.819  0.297114
# 0.822  0.305146
# ...         ...
# 5.795  0.724602
# 5.797  0.735981
# 5.800  0.726833
# 5.803  0.691284
# 5.805  0.706084
#
# [1259 rows x 1 columns]

# %%
import pickle

def scaler_pickling(scaler, file_name):
    import pickle
    with open(file_name, "wb") as f:
        pickle.dump(scaler, f)

# %%
scaler_pickling(scaler, "flask_app/website/static/byte_models/elbit_scaler.pkl")

# %% [markdown]
# Splitting to training, testing and validation sets
# train set: 0.70
# test set: 0.20
# val set: 0.10

# %%
total_len = len(num_df)-365
train_test_val = np.around([total_len * 0.7, total_len * 0.1, total_len * 0.2], decimals=0)
train_test_val = [int(i) for i in train_test_val]
train_test_val
# Out:
# [626, 89, 179]

# %% [markdown]
# train set = 626
# val set = 89
# test set = 179

# %% [markdown]
# Our Time Step Will Be 365 Days

# %%
X_train = []
y_train = []
X_val = []
y_val = []
X_test = []
y_test = []
time_step = 365
for i in range(time_step, len(num_df)):
    # Train Set
    if i < time_step + train_test_val[0]:
        X_train.append(num_df[i-time_step:i,0])
        y_train.append(num_df[i,0])
    elif time_step + train_test_val[0] <= i < time_step + train_test_val[0] + train_test_val[1]:
        X_val.append(num_df[i-time_step:i,0])
        y_val.append(num_df[i,0])
    else:
        X_test.append(num_df[i-time_step:i,0])
        y_test.append(num_df[i,0])

X_train = np.array(X_train)
y_train = np.array(y_train)

X_val = np.array(X_val)
y_val = np.array(y_val)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
print(len(X_train))
print(len(X_val))
print(len(X_test))
# Out:
# 626
# 89
# 179

# %% [markdown]
# Checking Our Shapes

# %%
X_train.shape
# Out:
# (626, 365)

# %% [markdown]
# We Want Our Shape To Be (x,x,1) for X
# and (x,1) for y

# %%
# For Train Sets
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
y_train = y_train.reshape(y_train.shape[0], 1)
print("X Train Shape:",X_train.shape, "| y Train Shape:", y_train.shape)
# Out:
# X Train Shape: (626, 365, 1) | y Train Shape: (626, 1)

# %%
# For val Sets
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
y_val = y_val.reshape(y_val.shape[0], 1)
print("X val Shape:",X_val.shape, "| y val Shape:", y_val.shape)
# Out:
# X val Shape: (89, 365, 1) | y val Shape: (89, 1)

# %%
# For test Sets
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
y_test = y_test.reshape(y_test.shape[0], 1)
print("X test Shape:",X_test.shape, "| y test Shape:", y_test.shape)
# Out:
# X test Shape: (179, 365, 1) | y test Shape: (179, 1)

# %% [markdown]
# Our Sets Are Ready Time To Set Up Our Model

# %%
regressor = Sequential()

regressor.add(LSTM(units=210, return_sequences=True, input_shape=(X_train.shape[1],1)))
# regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=200, return_sequences=True))
# regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=180, return_sequences=True))
# regressor.add(Dropout(0.2))
regressor.add(LSTM(units=210, return_sequences=False))
regressor.add(Dense(30))
regressor.add(Dense(1))

# %% [markdown]
# Compiling Using Adam

# %%
regressor.compile(optimizer=Adam(learning_rate=0.0026), loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %% [markdown]
# #### Summary

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 365, 210)          178080
#
#  lstm_1 (LSTM)               (None, 210)               353640
#
#  dense (Dense)               (None, 30)                6330
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 538,081
# Trainable params: 538,081
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Plotting Model Structure

# %%
tf.keras.utils.plot_model(regressor, show_shapes=True)

# %% [markdown]
# Training The Model

# %%
hist = regressor.fit(X_train,
                     y_train,
                     validation_data=(X_val, y_val),
                     epochs=10)
                     #callbacks=tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=0))
# Out:
# Epoch 1/10
# 2022-10-25 14:58:40.865934: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 20/20 [==============================] - 15s 667ms/step - loss: 0.0097 - root_mean_squared_error: 0.0985 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 2/10
# 20/20 [==============================] - 14s 693ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 3/10
# 20/20 [==============================] - 14s 703ms/step - loss: 8.7745e-04 - root_mean_squared_error: 0.0296 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0419
# Epoch 4/10
# 20/20 [==============================] - 14s 708ms/step - loss: 8.1369e-04 - root_mean_squared_error: 0.0285 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0405
# Epoch 5/10
# 20/20 [==============================] - 14s 711ms/step - loss: 7.2227e-04 - root_mean_squared_error: 0.0269 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 6/10
# 20/20 [==============================] - 14s 703ms/step - loss: 6.2863e-04 - root_mean_squared_error: 0.0251 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 7/10
# 20/20 [==============================] - 14s 706ms/step - loss: 6.1376e-04 - root_mean_squared_error: 0.0248 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 8/10
# 20/20 [==============================] - 14s 703ms/step - loss: 5.6876e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# Epoch 9/10
# 20/20 [==============================] - 14s 705ms/step - loss: 5.7405e-04 - root_mean_squared_error: 0.0240 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 10/10
# 20/20 [==============================] - 14s 706ms/step - loss: 6.6263e-04 - root_mean_squared_error: 0.0257 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325

# %% [markdown]
# Plotting Loss Over Time

# %%
pd.DataFrame(hist.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Predicting Baseline (train data)

# %%
y_train_pred = scaler.inverse_transform(regressor.predict(X_train))
y_train_true = scaler.inverse_transform(y_train)
plt.plot(y_train_pred, 'r')
plt.plot(y_train_true)
plt.legend(["Pred","Train"])
plt.show()
# Out:
# 20/20 [==============================] - 5s 215ms/step

# %% [markdown]
# Test Prediction

# %%
y_test_pred = scaler.inverse_transform(regressor.predict(X_test))
y_test_true = scaler.inverse_transform(y_test)
plt.plot(y_test_pred, 'r')
plt.plot(y_test_true)
plt.legend(["Pred","Train"])
plt.show()
# Out:
# 6/6 [==============================] - 1s 217ms/step

# %% [markdown]
# R2 Score For Model

# %%
np.round(r2_score(y_test_true, y_test_pred),decimals=2)
# Out:
# 0.8

# %% [markdown]
# 80% Accuracy For The Model IS A Good Starting Point

# %% [markdown]
# Creating a pickled version

# %% [markdown]
# pickling function

# %%
import pickle

def file_pickling(model, file_name):
    import pickle
    with open(file_name, "wb") as f:
        pickle.dump(model, f)

# %%
file_pickling(regressor, "byte_models/elbit.pkl")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://5e857ce5-d4ef-4331-a986-3a13f970bec7/assets
# INFO:tensorflow:Assets written to: ram://5e857ce5-d4ef-4331-a986-3a13f970bec7/assets
